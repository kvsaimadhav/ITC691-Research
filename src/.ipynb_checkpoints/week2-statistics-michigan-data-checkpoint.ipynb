# %%
import pandas as pd

data = pd.read_csv('michigan-history.csv')
data.head()
# Out:
#          date state dataQualityGrade    death  deathConfirmed  deathIncrease  \
# 0  2021-01-26    MI               A+  15305.0         14405.0             86
# 1  2021-01-25    MI               A+  15219.0         14326.0             38
# 2  2021-01-24    MI               A+  15181.0         14291.0              0
# 3  2021-01-23    MI               A+  15181.0         14291.0            230
# 4  2021-01-22    MI               A+  14951.0         14070.0             18
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            900           NaN                     NaN                 1638.0
# 1            893           NaN                     NaN                 1668.0
# 2            890           NaN                     NaN                 1843.0
# 3            890           NaN                     NaN                 1843.0
# 4            881           NaN                     NaN                 1843.0
#
#    ...  totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# 0  ...           9171401                     26969            481240.0
# 1  ...           9144432                     58323            479890.0
# 2  ...           9086109                         0            476180.0
# 3  ...           9086109                     52737            476180.0
# 4  ...           9033372                     44844            474589.0
#
#    totalTestsAntigen  totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# 0                NaN                       NaN                      NaN
# 1                NaN                       NaN                      NaN
# 2                NaN                       NaN                      NaN
# 3                NaN                       NaN                      NaN
# 4                NaN                       NaN                      NaN
#
#    totalTestsPeopleViral  totalTestsPeopleViralIncrease  totalTestsViral  \
# 0                    NaN                              0        9269199.0
# 1                    NaN                              0        9242391.0
# 2                    NaN                              0        9182223.0
# 3                    NaN                              0        9182223.0
# 4                    NaN                              0        9128298.0
#
#    totalTestsViralIncrease
# 0                    26808
# 1                    60168
# 2                        0
# 3                    53925
# 4                    44578
#
# [5 rows x 42 columns]

# %%
dimension = data.shape
rows = dimension[0]
cols = dimension[1]
print("Number of Rows in Dataset is ",rows)
print("Number of Columns in Dataset is ",cols)
# Out:
# Number of Rows in Dataset is  332
# Number of Columns in Dataset is  42

# %%
date = []
cases_diff = []
for i in range(0,rows):
    datevalue = data.iloc[i]["date"]
    date.append(datevalue)
    casesvalue = data.iloc[i]["positiveIncrease"]
    cases_diff.append(casesvalue)
print("The number of records in increase in COVID-19 cases in Michigan for each day is ", len(cases_diff))
print("The number of records in date is ", len(date))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'positiveCasesIncrease'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-0ff329f6dc35> in <module>
#       4     datevalue = data.iloc[i]["date"]
#       5     date.append(datevalue)
# ----> 6     casesvalue = data.iloc[i]["positiveCasesIncrease"]
#       7     cases_diff.append(casesvalue)
#       8 print("The number of records in increase in COVID-19 cases in Michigan for each day is ", len(cases_diff))
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if (
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     989
#     990         # Similar to Index.get_value, but we do not fall back to positional
# --> 991         loc = self.index.get_loc(label)
#     992         return self.index._get_values_for_loc(self, loc, label)
#     993
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 'positiveCasesIncrease'

# %%
records = len(cases_diff)
cases = []
date_reorder = []
for j in range(records-1,-1,-1):
    cases.append(cases_diff[j])
    date_reorder.append(date[j])
newdata = pd.DataFrame(list(zip(date_reorder,cases)))
newdata.columns = ['date', 'cases']
newdata.head()

# %%
dimension1 = newdata.shape
rows1 = dimension1[0]
cols1 = dimension1[1]
print("Rows in new data is ", rows1)
print("Columns in new data is ",cols1)

# %%
import numpy as np
difference = []
difference.append(np.nan)
for i in range(1,rows1):
    diff = newdata.iloc[i][1] - newdata.iloc[i-1][1]
    difference.append(diff)
newdata['difference'] = difference
newdata.tail()

# %%
newdata['index'] = newdata.index
ax1 = newdata.plot.scatter(x = 'index', y = 'difference', c = 'DarkBlue')

# %%
newdata.head()

# %%
for i in range(0,42):
    print(data.iloc[1][i])
