# %% [markdown]
# # Usage of Minimum and Saturating Values for Prediction of Data

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
 
data = pd.read_csv("michigan-history.csv")
data.head()
# Out:
# Importing plotly failed. Interactive plots will not work.
#          date state dataQualityGrade    death  deathConfirmed  deathIncrease  \
# 0  2021-01-26    MI               A+  15305.0         14405.0             86
# 1  2021-01-25    MI               A+  15219.0         14326.0             38
# 2  2021-01-24    MI               A+  15181.0         14291.0              0
# 3  2021-01-23    MI               A+  15181.0         14291.0            230
# 4  2021-01-22    MI               A+  14951.0         14070.0             18
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            900           NaN                     NaN                 1638.0
# 1            893           NaN                     NaN                 1668.0
# 2            890           NaN                     NaN                 1843.0
# 3            890           NaN                     NaN                 1843.0
# 4            881           NaN                     NaN                 1843.0
#
#    ...  totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# 0  ...           9171401                     26969            481240.0
# 1  ...           9144432                     58323            479890.0
# 2  ...           9086109                         0            476180.0
# 3  ...           9086109                     52737            476180.0
# 4  ...           9033372                     44844            474589.0
#
#    totalTestsAntigen  totalTestsPeopleAntibody  totalTestsPeopleAntigen  \
# 0                NaN                       NaN                      NaN
# 1                NaN                       NaN                      NaN
# 2                NaN                       NaN                      NaN
# 3                NaN                       NaN                      NaN
# 4                NaN                       NaN                      NaN
#
#    totalTestsPeopleViral  totalTestsPeopleViralIncrease  totalTestsViral  \
# 0                    NaN                              0        9269199.0
# 1                    NaN                              0        9242391.0
# 2                    NaN                              0        9182223.0
# 3                    NaN                              0        9182223.0
# 4                    NaN                              0        9128298.0
#
#    totalTestsViralIncrease
# 0                    26808
# 1                    60168
# 2                        0
# 3                    53925
# 4                    44578
#
# [5 rows x 42 columns]

# %%
dimension = data.shape
rows = dimension[0]
cols = dimension[1]
date = []
cases_diff = []
for i in range(0,rows):
    datevalue = data.iloc[i]["date"]
    date.append(datevalue)
    casesvalue = data.iloc[i]["positiveIncrease"]
    cases_diff.append(casesvalue)
records = len(cases_diff)
cases = []
date_reorder = []
for j in range(records-1,-1,-1):
    cases.append(cases_diff[j])
    date_reorder.append(date[j])
newdata = pd.DataFrame(list(zip(date_reorder,cases)))
newdata.columns = ['ds', 'y']
newdata.head()
# Out:
#            ds   y
# 0  2020-03-01   0
# 1  2020-03-02  13
# 2  2020-03-03  23
# 3  2020-03-04  24
# 4  2020-03-05  26

# %%
dimension1 = newdata.shape
rows1 = dimension1[0]
cols1 = dimension1[1]
per = 0.80 # percentage of data to be splitted in seqeuntial order
splitrows = int(per * rows1)
splitds = []
splity = []
column_names = ["ds", "y"]
for i in range(0,splitrows):
    splitds.append(newdata.iloc[i][0])
    splity.append(newdata.iloc[i][1])
splitdata = pd.DataFrame(list(zip(splitds,splity)),columns = column_names)
splitdata.head()
# Out:
#            ds   y
# 0  2020-03-01   0
# 1  2020-03-02  13
# 2  2020-03-03  23
# 3  2020-03-04  24
# 4  2020-03-05  26

# %%
from fbprophet import Prophet

m = Prophet()
m.fit(splitdata)
period = rows - splitrows
future = m.make_future_dataframe(periods = period)
future.tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#              ds
# 1057 2023-01-22
# 1058 2023-01-23
# 1059 2023-01-24
# 1060 2023-01-25
# 1061 2023-01-26

# %%
splitdata["floor"] = 0
future["floor"] = 0
splitdata["cap"] = max(splitdata["y"])
future["cap"] = max(splitdata["y"])
m = Prophet(growth='logistic')
m.fit(splitdata)
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fcst[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#           ds         yhat   yhat_lower   yhat_upper
# 0 2020-03-01 -1043.038982 -3763.426164  1676.898851
# 1 2020-03-02  1380.146539 -1225.633433  3976.467626
# 2 2020-03-03   549.192607 -2072.646875  3141.135603
# 3 2020-03-04   608.927203 -2116.823304  3163.445538
# 4 2020-03-05   468.867554 -2059.972711  3043.544023

# %%
#count = 0
diff = []
for i in range(splitrows,rows):
    #predlower = int(fcst.iloc[i][2])
    #predupper = int(fcst.iloc[i][3])
    predict =  int(fcst.iloc[i][1])
    actual = int(newdata.iloc[i][1])
    diff.append(abs(actual-predict))
    #print(predict, actual, predlower, predupper)
meanerror = sum(diff)/period
print("Mean Error in Prediction for 0-95% data is ", meanerror)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-cc1221a731e1> in <module>
#       8     diff.append(abs(actual-predict))
#       9     #print(predict, actual, predlower, predupper)
# ---> 10 meanerror = sum(diff)/period
#      11 print("Mean Error in Prediction for 0-95% data is ", meanerror)
#
# ZeroDivisionError: division by zero

# %%
count = 0
#diff = []
for i in range(splitrows,rows):
    predlower = int(fcst.iloc[i][2])
    predupper = int(fcst.iloc[i][3])
    predict =  int(fcst.iloc[i][1])
    actual = int(newdata.iloc[i][1])
    #diff.append(abs(actual-predict))
    #print(predict, actual, predlower, predupper)
    if(predlower > predupper):
        if(actual >= predupper and actual <= predlower):
            count = count + 1
    elif(predlower < predupper):
        if(actual >= predlower and actual >= predupper):
            count = count + 1
    else:
        if(actual == predlower and actual == predupper):
            count = count + 1
#meanerror = sum(diff)/period
print("Accuracy in Prediction for 95% data is ", (count/period)*100)

# %%
splitdata.to_csv('simulation.csv', index = False)
